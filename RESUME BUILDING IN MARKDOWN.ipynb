# %% [markdown]
#
#
# # <center> RESUME </center>
#
#  ![](data:image/jpeg;base64,...)
#
#
# ## PERSONAL INFORMATION
#
# Name      : Anjali Pabboju
#
#
# Linked In : https://www.linkedin.com/in/anjali-pabboju-087b00252
#
#
# E-mail    : anjalipabboju333@gmail.com
#
#
# GitHub    : https://github.com/signup
#
#
# ## CAREER OBJECTIVE
#
# To work in a firm with a professional work driven environment which provides an opportunity to enhance my skills and knowledge
#
# and utilize them for personal and organizational growth.
#
#
# ## EDUCATION
#
# <b> BSc Data Science </b>
#
# Government Degree College,Siddipet | May 2023
#
# <b> MPC </b>
#
# Masterminds Junior College,Siddipet | 2020
#
# <b> SSC </b>
#
# Scholars High School,Siddipet | 2018
#
#
# ## TECHNICAL SKILLS
#
# Operating System: Windows, Unix
#
# Programming Languages : Python,R,SQL
#
# Machine Learning: Linear regression, Logistic regres sion, Decision tree,K nearest neighbour, K mean
#
# Databases     : MySQL,MongoDB,SQL Server
#
# Data Analysis : Numpy,Pandas
#
# Data Visualtization : Tableau,Matplotlib
#
#
# ## PROJECTS
#
# <b> SUDOKU GAME USING PYTHON </b>
#
# A console-based puzzle where players fill a 9x9 grid with digits 1-9, ensuring each row, column, and 3x3 subgrid contains all   digits. The game employs logic and problem-solving skills for an engaging challenge.
#
# <b> JACK VOICE ASSISTENT </b>
#
#  A speech-driven tool utilizing natural language processing to aid data professionals. It answers queries, performs analyses, and offers insights, enhancing efficiency and accessibility in data tasks.
#
# <b> THYVIEW MOVIE RECOMMANDATION SYSTEM </b>
#
# Utilizes collaborative filtering or content-based algorithms to analyze user preferences and movie attributes, suggesting personalized movie choices. Enhances user experience by delivering tailored recommendations, employing data science techniques for accurate predictions.
#
#
#
#
# ## CERTIFICATIONS
#
# * Fundamentals of Data Science | Udemy
#
# * Python | Coursera
#
# * Azure Data Scientist Associate | Microsoft Certified
#
# * Certified Machine Learning | Amazon Web Services (AWS)
#
# ## WORKSHOPS
#
# * National level one day workshop on "ARTIFICIAL INTELLIGENCE AND ITS APPLICATIONS".
#
# * 1 month workshop on MACHINE LEARNING
#
#
# ## ACHEIVEMENTS
#
# * Participed in Gignyasa Project (Data Science)
#
# * Got second rank in Talent Test
#
# * Successfully managed work-life balance during challenging times.
#
#
# ##  LANGUAGES
#
# * English
#
# * Hindi
#
#
# ## Declaration
#
# I hereby declare that the above furnished information is true to the best of my knowledge and belief.
